# %% [markdown]
# # Exploratory Analysis on  the life expectancy Dataset
#
# Getting a First feel of the dataset and having an high level understanding of the features and there distribution.
#
# Moreso, Looking out for interesting pattern and insight.
#
# _Have fun!!!_

# %%
# importing the require library for analysis

import pandas as pd

import matplotlib.pyplot as plt

import seaborn as  sns

import numpy as np

# %matplotlib inline

sns.set_style("darkgrid")

# %%
# Read in dataset

df = pd.read_csv("Life_Expectancy_Data.csv")
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %% [markdown]
# From the above the columns name appear to have a space. this will create a problem in accessing the column name. Hence there is a need to rename the column so that there are no space inbetween the name
#
# __Rename Columns__

# %%
# display the shape of the dataset
df.shape
# Out:
# (2938, 22)

# %%
# renaming the columns for accessing the feature easily
new_columns_names =['country','year','status','life_expectancy','adult_mortality','infant_deaths','alcohol','percentage_expenditure','hepatitis_b','measles','bmi','under_five_deaths','polio','total_expenditure','diphtheria','hiv_aids','gdp','population','thinness_1_19_years','thinness_5_9_years','income_composition_of_resources','schooling']
df.columns = new_columns_names

# %%
df.dtypes
# Out:
# country                             object
# year                                 int64
# status                              object
# life_expectancy                    float64
# adult_mortality                    float64
# infant_deaths                        int64
# alcohol                            float64
# percentage_expenditure             float64
# hepatitis_b                        float64
# measles                              int64
# bmi                                float64
# under_five_deaths                    int64
# polio                              float64
# total_expenditure                  float64
# diphtheria                         float64
# hiv_aids                           float64
# gdp                                float64
# population                         float64
# thinness_1_19_years                float64
# thinness_5_9_years                 float64
# income_composition_of_resources    float64
# schooling                          float64
# ...

# %%
# summary statistics
df.describe()
# Out:
#               year  life_expectancy  adult_mortality  infant_deaths  \
# count  2938.000000      2928.000000      2928.000000    2938.000000
# mean   2007.518720        69.224932       164.796448      30.303948
# std       4.613841         9.523867       124.292079     117.926501
# min    2000.000000        36.300000         1.000000       0.000000
# 25%    2004.000000        63.100000        74.000000       0.000000
# 50%    2008.000000        72.100000       144.000000       3.000000
# 75%    2012.000000        75.700000       228.000000      22.000000
# max    2015.000000        89.000000       723.000000    1800.000000
#
#            alcohol  percentage_expenditure  hepatitis_b        measles  \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %% [markdown]
# Checking the summary statistics and examing the standard deviation and the mean shows that the features are not on the same scale thus there is a need to standardize the dataset

# %% [markdown]
# # II. Distributions
# Examining the distribution of the features in the dataset

# %%
# plot histogram grid
df.hist(figsize=(14,14), xrot=-45)

# clear the text "residue"
plt.show()

# %% [markdown]
# ### Examining the plot of the plot of the categorical features

# %%
# summarize categorical features
df.describe(include=['object'])
# Out:
#             country      status
# count          2938        2938
# unique          193           2
# top     Afghanistan  Developing
# freq             16        2426

# %%
df.status.unique()
# Out:
# array(['Developing', 'Developed'], dtype=object)

# %% [markdown]
# The feature status tells the country that

# %%
sns.countplot(y='status', data=df)
plt.show()

# %% [markdown]
# # III. Segmentations
# Observing the relationship between categorical and numeric features

# %%
# Segment life expectancy by status
sns.boxplot(y='status', x='life_expectancy', data=df)
plt.show()

# %% [markdown]
# From the above plot it appears :
#
# * That developed country appears to have high life expectancy as compare to developing country.
#
# * It also reveals some outlier in the developing feature- we need to understand and know this outlier, moreso why we are they present in the dataset
#
# * This outlier seems to below the outside the minimum values( i.e outside the range of the values)
#
# * The average(mean) life expectancy of developing feature is close to 70 while for the developed is close to 80

# %%
# segement by status  and display the means within each class
df.groupby('status').mean()
# Out:
#                    year  life_expectancy  adult_mortality  infant_deaths  \
# status
# Developed   2007.500000        79.197852        79.685547       1.494141
# Developing  2007.522671        67.111465       182.833195      36.384171
#
#              alcohol  percentage_expenditure  hepatitis_b      measles  \
# status
# Developed   9.826736             2703.600380    88.041298   499.005859
# Developing  3.484119              323.470285    79.763930  2824.926216
#
#                   bmi  under_five_deaths      polio  total_expenditure  \
# status
# Developed   51.803906           1.810547  93.736328           7.554042
# Developing  35.435326          50.525144  80.170752           5.590694
#
#             diphtheria  hiv_aids           gdp    population  \
# status
# Developed    93.476562  0.100000  22053.386446  6.830053e+06
# Developing   79.951807  2.088664   4286.556053  1.407108e+07
#
#             thinness_1_19_years  thinness_5_9_years  \
# status
# ...

# %% [markdown]
# _There are some interesting fact to note from the above_:
#
# * life expectancy in developed country is high as compare to developing country
# * The adult mortality rate is high in developing country meaning there is high number of adult death in developing country
# * Develop country tends to consume more alcohol as compare to developing - why this?
# * Heath care expenditure is duly pay attention to in developed countries
# * Measles disease seems to be more prevalent in developing countries
# * Developed  country seems to have high BMI and this shows that there more people obese as compare to developing country
#
# * developed countries has a high gross domestic product as compare to developing countries
#
# * population in developing countries is high
#
# The insight here is endless- we will come back to it later

# %%
# Calculate correlations between numeric features
correlations = df.corr()

# %%
# Increase the figsize to 7 x 6
plt.figure(figsize=(9,9))

# Plot heatmap of correlations
sns.heatmap(correlations, cmap='RdBu_r')
plt.show()

# %% [markdown]
# The above heatmap could not tells us because the color seems to be much to pick the correlations appears difficulty. Hence we will use a triangular heatmap with percentage to see the correlations among the numeric features

# %%
# Generate a mask for the upper triangle
mask = np.zeros_like(correlations)
mask[np.triu_indices_from(mask)] = 1

# Option 2: Mask of False/True
# mask = np.zeros_like(correlations, dtype=np.bool)
# mask[np.triu_indices_from(mask)] = True

# %%
# Make the figsize 10 x 8
plt.figure(figsize=(10,8))

# Plot heatmap of correlations
sns.heatmap(correlations * 100,
            cmap='RdBu_r',
            annot=True,
            fmt='.0f',
            mask=mask)
plt.show()

# %% [markdown]
# Insight from the above plot:
# The following appears to be highly correlated with target variable-
# * schooling
# * income_composition_of_resources
# * adult_mortality ( -ve correlation)
#
#
# The following features appears to be correlated with each-
# * infant_deaths and under_five_deaths are strongly correlated
# * percentage_expenditure and gdp
# *  some correlation between hepatitis b and diphtheria
# * income_composition_resources and schooling
# * thinness 1_19 and thinness 5_9
# * polio and diphtheria seems to be correlated fairly
#
# This will be examine mucn more in created depth

# %%
# Examining the relationship between the status and life_expectancy

sns.violinplot(y='status', x='life_expectancy', data=df)
plt.show()

# %%
# Scatterplot of schooling vs. .life expectancy
sns.lmplot(x='schooling',
           y='life_expectancy',
           hue='status',
           data=df,
           fit_reg=False,
           scatter_kws={'alpha':0.1})
plt.show()

# %% [markdown]
# An upward trends is seen- this imply as the schooling rate increase the life expectancy increase, moreso developed country have high life_expectancy and the schoolling rate is high

# %%
# The relationship between status and income_composition_of_resources
sns.boxplot(y='status', x='income_composition_of_resources', data=df)
plt.show()

# %% [markdown]
# The income compostion of resources is high in developed countries and their appears to be outlier in the Developing countries and this is below the minimun value . could the dataset contain negative values for income?

# %%
# The income distribution of the income 
sns.violinplot(y='status', x='income_composition_of_resources', data=df)
plt.show()

# %% [markdown]
# The above shows how the income of developed and developing countries are distributed
# * for developing country : there appears to income division class - from 0.0 -0.1, 0.3 -0.6 and 0.6 - 0.9

# %%
# Scatterplot of income_composition vs expectancy
sns.lmplot(x='income_composition_of_resources',
           y='life_expectancy',
           hue='status',
           data=df,
           fit_reg=False,
           scatter_kws={'alpha':0.1})
plt.show()

# %%
# relationship between  adult mortality and life expectancy for developed and developing countries
sns.lmplot(x='adult_mortality',
           y='life_expectancy',
           hue='status',
           data=df,
           fit_reg=False,
           scatter_kws={'alpha':0.1})
plt.show()

# %% [markdown]
# The life expectancy decrease as the adult mortality increase
